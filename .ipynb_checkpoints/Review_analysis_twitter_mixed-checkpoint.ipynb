# %%
cd PycharmProjects/motoki_ul/review_analysis
# Out:
# [Errno 2] No such file or directory: 'PycharmProjects/motoki_ul/review_analysis'
# /Users/motoki/PycharmProjects/motoki_ul/review_analysis

# %%
##Clean raw data & prepare for analytics

import pandas as pd

input_dir = "/Users/motoki/PycharmProjects/motoki_ul/review_analysis/input_dir/twitter_mixed"
df = pd.read_csv(f"{input_dir}/twitter_raw.csv")
df.fillna("。")

#Replace \n in caption (This causes Attribute error on MeCab)
df_new = df
df_new["caption"] = df_new["hashtag"].fillna("。").str.cat(" " + df_new["text"])
caption = []
for i in df['caption']:
    caption.append(str(i).replace('\n',''))
df_new["caption"] = caption
print(df_new)

#Combine comments on each product (for Doc2Vec)
df_new['kwd'] = df_new['query']
df_new_combined = df_new.groupby(["tweet_id", "kwd"])["caption"].sum().reset_index()
display(df_new_combined)
# Out:
#      Unnamed: 0                created_at query      tweet_id     author_id  \
# 0             0  2021-06-29T01:26:17.000Z  ルイボス  1.409680e+18  2.906805e+09
# 1             1  2021-06-29T01:22:58.000Z  ルイボス  1.409680e+18  1.327430e+18
# 2             2  2021-06-29T00:32:35.000Z  ルイボス  1.409670e+18  9.692388e+07
# 3             3  2021-06-29T00:22:42.000Z  ルイボス  1.409670e+18  5.566155e+08
# 4             4  2021-06-28T23:32:50.000Z  ルイボス  1.409660e+18  1.562875e+08
# ...         ...                       ...   ...           ...           ...
# 1191       1179  2021-06-22T03:12:54.000Z  ルイボス  1.407170e+18  2.210051e+08
# 1192       1180  2021-06-22T03:05:57.000Z  ルイボス  1.407170e+18  1.330870e+18
# 1193       1181  2021-06-22T02:49:28.000Z  ルイボス  1.407170e+18  1.044625e+09
# 1194       1182  2021-06-22T02:44:42.000Z  ルイボス  1.407170e+18  5.493595e+08
# 1195       1183  2021-06-22T02:24:40.000Z  ルイボス  1.407160e+18  9.833200e+17
#
#       retweet_count  reply_count  like_count  quote_count            mentions  \
# 0               0.0          0.0         0.0          0.0        ['elbee_jp']
# 1               0.0          0.0         4.0          0.0                 NaN
# 2               0.0          0.0         9.0          0.0                 NaN
# 3               0.0          0.0         0.0          0.0  ['tartetatatin06']
# 4               0.0          0.0         4.0          0.0                 NaN
# ...             ...          ...         ...          ...                 ...
# 1191            0.0          0.0         0.0          0.0                 NaN
# 1192            0.0          1.0         2.0          0.0                 NaN
# 1193            0.0          0.0         0.0          0.0         ['xmas_no']
# 1194            0.0          1.0        16.0          0.0                 NaN
# 1195            0.0          0.0         1.0          0.0  ['hitomi44116516']
#
#                                                     url  \
# 0                                                   NaN
# 1                           ['https://t.co/Q3Gs83bkuR']
# 2                           ['https://t.co/8RoA9K3gF6']
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1191                                                NaN
# 1192                                                NaN
# 1193                                                NaN
# 1194  ['https://t.co/iI6m4yYHtF', 'https://t.co/iI6m...
# 1195                                                NaN
#
#                                                    text      hashtag  \
# 0                              @elbee_jp ルイボスじゃなくて良かった✨          NaN
# 1     これ美味しい〜😊\nルイボスだしカフェインはいってないよ💞 https://t.co/Q3G...          NaN
# 2     毎日飄々とツイートしていますが、ルイボスも個人のお客様だけではなく、飲食店さんとも話をはじめ...  ['ルイボスティー']
# 3     @tartetatatin06 後期はやっぱりかなり浮腫むみたいですよね…！今も浮腫んでます...          NaN
# 4     昨日仕込んだルイボスティー寒天、タッパーいっぱいに作って美味しく出来ました。\n朝御飯に食べ...          NaN
# ...                                                 ...          ...
# 1191                 リプトンのルイボスパンチほぼ桃ジュースなのでもう少しルイボス感欲しい          NaN
# 1192  相変わらずアイスティーばっかり飲んでる。麦茶は冷たければいける、ルイボス・緑茶はムリ。水もあ...          NaN
# 1193                     @xmas_no ちゃんとルイボスも送ってくれたんですね！笑          NaN
# 1194  昨日、イオンに行ったら見つけたので、お迎えしたよ🥰\n加州かルイボスなのがまた嬉しい💕\n\...          NaN
# 1195  @hitomi44116516 こあらママちゃんおはよう♥😊\n\nそうなのー！夕方から飲ま...          NaN
#
#                                                 caption
# 0                            。 @elbee_jp ルイボスじゃなくて良かった✨
# 1     。 これ美味しい〜😊ルイボスだしカフェインはいってないよ💞 https://t.co/Q3G...
# 2     ['ルイボスティー'] 毎日飄々とツイートしていますが、ルイボスも個人のお客様だけではなく、...
# 3     。 @tartetatatin06 後期はやっぱりかなり浮腫むみたいですよね…！今も浮腫んで...
# 4     。 昨日仕込んだルイボスティー寒天、タッパーいっぱいに作って美味しく出来ました。朝御飯に食べ...
# ...                                                 ...
# 1191               。 リプトンのルイボスパンチほぼ桃ジュースなのでもう少しルイボス感欲しい
# 1192  。 相変わらずアイスティーばっかり飲んでる。麦茶は冷たければいける、ルイボス・緑茶はムリ。水...
# 1193                   。 @xmas_no ちゃんとルイボスも送ってくれたんですね！笑
# 1194  。 昨日、イオンに行ったら見つけたので、お迎えしたよ🥰加州かルイボスなのがまた嬉しい💕日光さ...
# 1195  。 @hitomi44116516 こあらママちゃんおはよう♥😊そうなのー！夕方から飲まない...
#
# [1196 rows x 14 columns]
#          tweet_id   kwd                                            caption
# 0    1.407160e+18  ルイボス  。 @hitomi44116516 こあらママちゃんおはよう♥😊そうなのー！夕方から飲まない...
# 1    1.407170e+18  ルイボス  。 リプトンのルイボスパンチほぼ桃ジュースなのでもう少しルイボス感欲しい。 相変わらずアイス...
# 2    1.407180e+18  ルイボス  。 ティーライフ の ティーライフ ルイボスティー 2.0g×101個 (ノンカフェイン ル...
# 3    1.407190e+18  ルイボス  ['クーポン利用で1000円ポッキリ送料無料', '楽天お買い物マラソン', 'ルイボスティ...
# 4    1.407200e+18  ルイボス  。 @hiyokko_home ひよっこさん、こんぴよ💚キンキンに冷えたルイボス、いいですね...
# ..            ...   ...                                                ...
# 206  1.409640e+18  ルイボス            。 @ruibosu0222 沖縄雨凄いですね‼️ルイボスさん大丈夫ですか❓️
# 207  1.409650e+18  ルイボス                  。 ルイボスてぃー？茶？とけジャスミンてぃー？茶？っておいしいん？
# 208  1.409660e+18  ルイボス  。 昨日仕込んだルイボスティー寒天、タッパーいっぱいに作って美味しく出来ました。朝御飯に食べ...
# 209  1.409670e+18  ルイボス  ['ルイボスティー'] 毎日飄々とツイートしていますが、ルイボスも個人のお客様だけではなく、...
# 210  1.409680e+18  ルイボス  。 @elbee_jp ルイボスじゃなくて良かった✨。 これ美味しい〜😊ルイボスだしカフェイ...
#
# [211 rows x 3 columns]

# %%
##Split into words and visualize

from sklearn.feature_extraction import stop_words
from collections import Counter, defaultdict
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
import MeCab
import sys
import urllib
import nltk
import string
import re
import numpy as np

# %matplotlib inline
plt.rcParams["font.family"] = "IPAexGothic"

tagger = MeCab.Tagger('-Owakati')
tagger.parse(" ")
tagger.parseToNode('ダミー')

class CustomMeCabTagger(MeCab.Tagger):

    COLUMNS = ["表層形", "品詞", "品詞細分類1", "品詞細分類2", "品詞細分類3", "活用型", "活用形", "原形", "読み", "発音"]

    def parseToDataFrame(self, text: str) -> pd.DataFrame:
        """テキストを parse した結果を Pandas DataFrame として返す"""
        results = []
        #Mecabの出力方式に基づく。(表層系\t品詞,品詞細分類...)
        #まずは改行で分けて単語自体を区分する
        text_unlisted = " ".join([i for item in text for i in item])
        for line in self.parse(text_unlisted).split("\n"):
            #EOS = end of statement, no more words
            if line == "EOS":
                break
            #Split word itself and feature by "tab"
            surface, feature = line.split("\t")
            #Put None if the content is "*" (means nothing)
            feature = [None if f == "*" else f for f in feature.split(",")]
            results.append([surface, *feature])
        return pd.DataFrame(results, columns=type(self).COLUMNS)

def get_dokuritsugo_by_mecab(text):
    #tagger = MeCab.Tagger('-Owakati')
    #tagger.parse(" ") 
    node = tagger.parseToNode(text)
    word_list = []
    while node:
        pos = node.feature.split(",")[0]
        #only needs below (others don't have meanings in this context)
        if pos in ["名詞", "動詞", "形容詞"]:
            word = node.surface
            word_list.append(word)
        node = node.next
    return " ".join(word_list)

df_new["cleared_words"] = df_new["caption"].apply(lambda x : get_dokuritsugo_by_mecab(x))

stop_words_all = []
#define stopword (English)
nltk.download("stopwords")
stop_words_sklearn = stop_words.ENGLISH_STOP_WORDS
stop_words_nltk = nltk.corpus.stopwords.words("english")
stop_words_nltk.extend(stop_words_sklearn)
stop_words_all = stop_words_nltk

#define stopword (Japanese)
slothlib_path = "http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/Japanese.txt"
slothlib_file = urllib.request.urlopen(slothlib_path)
slothlib_stopwords = [line.decode("utf-8").strip() for line in slothlib_file]
slothlib_stopwords = [ss for ss in slothlib_stopwords if not ss==u'']
stop_words_all.extend(slothlib_stopwords)

#define manual stopword
add_words=["'",u"それ",u"てる",u"よう",u"こと",u"の",u"し",u"い",u"ん",u"さ",u"て",u"せ",u"れ"]
stop_words_all.extend(add_words)

def del_stop_words(text):
    #replace all the punctuations by using re.sub()
    regex = re.compile('[' +re.escape(string.punctuation) + '0-9\\r\\t\\n]')
    sample = regex.sub("", text)
    
    #change to lower case and check if it's in stop words list
    words = [w.lower()  for w in sample.split(" ") \
                 if not w.lower()  in stop_words_all]
    words=" ".join(words)
    return words

def del_single_used_words(text):
    #delete words only used once
    frequency = defaultdict(int)
    for words in text:
        for token in words:
            frequency[token] += 1
    words = [[token for token in words if frequency[token] > 1] for words in text]
    return words

df_new["cleared_stopwords"] = list(df_new["cleared_words"].apply(lambda x: del_stop_words(x)))
text = del_single_used_words([i.split(" ") for i in df_new["cleared_stopwords"]])

##Make combined list for doc2vec (now also used for LDA&word2Vec)
df_new_combined["cleared_words"] = df_new_combined["caption"].apply(lambda x : get_dokuritsugo_by_mecab(x))
df_new_combined["cleared_stopwords"]=list(df_new_combined["cleared_words"].apply(lambda x: del_stop_words(x)))
text_combined = del_single_used_words([i.split(" ") for i in df_new_combined["cleared_stopwords"]])

#finally make dataframe of wordlist splitted by MeCab
tagger = CustomMeCabTagger()
result = tagger.parseToDataFrame(text_combined)

counter_list = []
for i in result["表層形"]:
    counter_list.append(i)
word_count = Counter(counter_list)

df_count = pd.DataFrame.from_dict(word_count,orient='index').reset_index()
df_count.columns=["word","count"]
df_count.sort_values("count",ascending=False,inplace=True)
df_count = df_count.iloc[1:,:]

print(df_count.head(30))

#Visualization for word count graph
plt.figure(figsize = (30,20))
ax=df_count.iloc[:20,:].plot.bar()
ax.set_ylabel("Frequency",fontsize=15)
ax.set_xticklabels(
    df_count.iloc[:20,:]["word"], fontdict = {
        'fontsize':10})
ax.legend_.remove()
plt.style.use('seaborn-whitegrid')
plt.show()

fpath = "/Users/motoki/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/ipaexg.ttf"
#Visualization for word cloud
wc_bz = WordCloud(
    background_color="white",
    width=600,
    height=400,
    max_words=3000,
    max_font_size=70,
    font_path=fpath,
    prefer_horizontal=1,
    include_numbers=True,
    colormap='tab20',
    regexp=r"[\w']+")
wc_bz.generate_from_frequencies(word_count)

plt.figure(figsize = (21,12))
#sns.set_style("whitegrid")
plt.imshow(wc_bz, interpolation="bilinear")
plt.axis("off")
plt.style.use('seaborn-whitegrid')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/motoki/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#         word  count
# 901        ぽ   1791
# 8         ボス   1235
# 7         ルイ   1235
# 62        rt    654
# 430       健康    638
# 604        出    611
# 32        言っ    604
# 235        っ    602
# 756       体重    601
# 909       cm    598
# 902       素人    598
# 910      リスク    598
# 911       来る    598
# 907       切っ    598
# 908     スタート    597
# 906       身長    597
# 904       玄人    597
# 905      言える    597
# 903      ちゃり    597
# 900   suzuki    597
# 899      jun    597
# 54         茶    288
# 49     https    242
# 50       ティー    207
# 52   ルイボスティー    147
# 31     カフェイン    120
# 56        お茶     98
# 11        飲ん     84
# 97         包     79
# 86        紅茶     69

# %%
# word frequency output to csv

import datetime

now = datetime.datetime.today()
today = now.strftime("%Y%m%d")
category = "tea"

output_dir = "/Users/motoki/PycharmProjects/motoki_ul/review_analysis/output_dir/twitter_mixed"
filename = f"{today}_{category}_twitter.csv"
df_count.to_csv(f"{output_dir}/{filename}")

df_count
# Out:
#      word  count
# 901     ぽ   1791
# 8      ボス   1235
# 7      ルイ   1235
# 62     rt    654
# 430    健康    638
# ...   ...    ...
# 1154   洒落      1
# 278     愛      1
# 647    ロー      1
# 996     無      1
# 366    まっ      1
#
# [1195 rows x 2 columns]

# %%
##TF-IDF analysis
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

df_new_combined["cleared_words"] = df_new_combined["caption"].apply(lambda x : get_dokuritsugo_by_mecab(x))
df_new_combined["cleared_stopwords"] = df_new_combined["cleared_words"].apply(lambda x: del_stop_words(x))
text_combined_tfidf = [i for i in df_new_combined["cleared_stopwords"]]

vectorizer = TfidfVectorizer()
X=vectorizer.fit_transform(text_combined_tfidf)
X=X.toarray()

idf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
df_idf = pd.DataFrame(columns=['idf']).from_dict(
                    dict(idf), orient='index')
df_idf.columns = ['idf']
display(df_idf.sort_values("idf").head(10).T)
# Out:
#            ボス        ルイ     https       ティー   ルイボスティー     カフェイン        お茶  \
# idf  1.019048  1.019048  1.386773  1.813291  1.856777  1.949867  2.052521
#
#            rt        飲ん        健康
# idf  2.066127  2.182199  2.197703

# %%
##t-SNE for TF-IDF
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

tsne= TSNE(n_components=2, verbose=1, n_iter=500)
tsne_tfidf = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 211 samples in 0.006s...
# [t-SNE] Computed neighbors for 211 samples in 0.136s...
# [t-SNE] Computed conditional probabilities for sample 211 / 211
# [t-SNE] Mean sigma: 0.308386
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.938820
# [t-SNE] KL divergence after 500 iterations: 0.878651

# %%
#Put in DataFrame
df_tsne = pd.DataFrame(tsne_tfidf[:,0],columns = ["x"])
df_tsne["y"] = pd.DataFrame(tsne_tfidf[:,1])
df_tsne["tweet_id"]=df_new_combined.tweet_id
df_tsne["kwd"]=df_new_combined.kwd

pd.set_option('display.max_rows', 1000)
display(df_tsne.head(10))
# Out:
#            x          y      tweet_id   kwd
# 0  -7.551743 -19.886290  1.407160e+18  ルイボス
# 1   9.592683   7.340742  1.407170e+18  ルイボス
# 2  -0.831305  -5.121915  1.407180e+18  ルイボス
# 3  -3.278805 -11.343933  1.407190e+18  ルイボス
# 4  19.995371  -2.226655  1.407200e+18  ルイボス
# 5  12.075490   9.987938  1.407210e+18  ルイボス
# 6  21.539351   5.317097  1.407220e+18  ルイボス
# 7  12.325998  -2.117732  1.407230e+18  ルイボス
# 8   4.208718   5.945292  1.407240e+18  ルイボス
# 9  18.554375  -0.670530  1.407250e+18  ルイボス

# %%
##Visualization
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.rcParams['font.family'] = 'IPAexGothic'

#A: Overlook
fig_overview = plt.figure(figsize=(10.0, 10.0))
for f in df_tsne['kwd'].unique():
    plt.scatter(df_tsne.loc[df_tsne.kwd == f ,'x'], df_tsne.loc[df_tsne.kwd == f ,'y'], label=f)

plt.legend()
plt.title("TF-IDF-overview-")
plt.show()

#B: Detail
fig_detail = plt.figure(figsize=(50.0, 30.0))
for f in df_tsne['kwd'].unique():
    plt.scatter(df_tsne.loc[df_tsne.kwd== f ,'x'], df_tsne.loc[df_tsne.kwd == f ,'y'], label=f)

for i, txt in enumerate(df_tsne["tweet_id"].values):
    plt.annotate(txt, (df_tsne["x"].values[i], df_tsne["y"].values[i]), fontsize=8)
    
plt.legend()
plt.title("TF-IDF")
plt.show()

# %%
##LDA analytics (after filtering TF-IDF)

import gensim
from gensim import corpora, models

#Dictionary is the set of "word ID, word, frequency" data (can be saved)
dictionary =corpora.Dictionary(text)
corpus = [dictionary.doc2bow(doc) for doc in text_combined]

#Can filter TF-IDF before LDA
#TF = Term Frequency -> frequency of each word (the bigger, the more important)
#IDF = Inverse document frequency -> filtering too high frequent words like "a, the, there etc.."
#Below is the class for TF-IDF analytics
#tfidf = gensim.models.TfidfModel(corpus)
#corpus_tfidf = tfidf[corpus]

#Number of topics
zk = 5
#Learning model (can be saved)
lda = gensim.models.LdaModel(corpus=corpus, id2word=dictionary,
                             num_topics=zk, minimum_probability=0.001,
                             passes=20, update_every=0, chunksize=10000)

l = []
for i in range(zk):
    print('tpc_{0}: {1}'.format(i, lda.print_topic(i)[0:80]+'...'))
    l.append('tpc_{0}: {1}'.format(i, lda.print_topic(i)[0:80]+'...'))

name_file = 'topic.csv'
with open (name_file, mode='w') as f:
    f.write(l)
# Out:
# tpc_0: 0.049*"" + 0.018*"ボス" + 0.017*"ルイ" + 0.010*"ー" + 0.010*"ルイボスティー" + 0.009*"https"...
# tpc_1: 0.222*"" + 0.046*"ボス" + 0.046*"ルイ" + 0.025*"茶" + 0.025*"ルイボスティー" + 0.024*"https"...
# tpc_2: 0.271*"" + 0.026*"ルイ" + 0.026*"ボス" + 0.026*"茶" + 0.021*"ダイエット" + 0.015*"ティー" + 0...
# tpc_3: 0.171*"" + 0.059*"ルイ" + 0.059*"ボス" + 0.019*"茶" + 0.017*"https" + 0.011*"飲ん" + 0....
# tpc_4: 0.268*"" + 0.105*"kg" + 0.078*"ぽ" + 0.028*"ルイ" + 0.028*"ボス" + 0.026*"健康" + 0.026...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-906e8f34ed91> in <module>
#      29 name_file = 'topic.csv'
#      30 with open (name_file, mode='w') as f:
# ---> 31     write(f)
#
# NameError: name 'write' is not defined

# %%
#Make Numpy b/w Products & topics
Prob_products=np.array(lda.get_document_topics(corpus,minimum_probability=0))[:,:,1]

#Put in DataFrame
L=[ z for z in range(1,zk+1)]
col_name=list(map(lambda x: "Prob_"+str(x),L))
df_prob=pd.DataFrame(Prob_products)
df_prob.columns=col_name

#Add product name & most likely belonging topic No.
df_prob["Max"]=df_prob.idxmax(axis=1)
def del_Prob(x):
    return int(x.split("_")[1])
df_prob["Max"]=df_prob["Max"].apply(lambda x : del_Prob(x))
df_prob.insert(0, "tweet_id", df_new_combined["tweet_id"])
display(df_prob.head(30))

#Calculate probability of apperance of each topic
df_topic=pd.DataFrame(df_prob.drop(["Max", "tweet_id"],axis=1).sum()/df_prob.drop(["Max", "tweet_id"],axis=1).sum().sum())
df_topic.columns=["Prob"]
df_topic["Topic"]=[ z for z in range(1,zk+1)]

#Visualization
plt.figure(figsize = (30,20))
ax= sns.barplot(x="Topic",y="Prob",data=df_topic,color="darkblue")
ax.set_xlabel("Topic",fontsize=50)
ax.set_ylabel("Prob",fontsize=50)
ax.tick_params(axis='x', labelsize=40)
ax.tick_params(axis='y', labelsize=40)
plt.show()
# Out:
#         tweet_id    Prob_1    Prob_2    Prob_3    Prob_4  Max
# 0   1.407160e+18  0.011015  0.011296  0.965671  0.012019    3
# 1   1.407170e+18  0.033933  0.005404  0.005119  0.955544    4
# 2   1.407180e+18  0.002613  0.713343  0.002735  0.281309    2
# 3   1.407190e+18  0.002567  0.992220  0.002615  0.002598    2
# 4   1.407200e+18  0.004561  0.004692  0.051072  0.939675    4
# 5   1.407210e+18  0.002440  0.002515  0.002469  0.992576    4
# 6   1.407220e+18  0.017418  0.017551  0.017575  0.947457    4
# 7   1.407230e+18  0.006836  0.007014  0.007037  0.979112    4
# 8   1.407240e+18  0.036919  0.004938  0.475660  0.482482    4
# 9   1.407250e+18  0.063820  0.068001  0.069254  0.798925    4
# 10  1.407260e+18  0.017814  0.002735  0.687299  0.292152    3
# 11  1.407270e+18  0.002931  0.003030  0.769904  0.224136    3
# 12  1.407280e+18  0.001475  0.924781  0.001474  0.072270    2
# 13  1.407290e+18  0.004223  0.457647  0.533878  0.004252    3
# 14  1.407300e+18  0.002651  0.002692  0.002648  0.992009    4
# 15  1.407310e+18  0.002626  0.002702  0.002729  0.991943    4
# 16  1.407320e+18  0.005484  0.005561  0.637002  0.351954    3
# 17  1.407330e+18  0.001909  0.829945  0.001965  0.166181    2
# 18  1.407340e+18  0.030770  0.049357  0.004674  0.915200    4
# 19  1.407350e+18  0.005632  0.005727  0.983094  0.005547    3
# 20  1.407360e+18  0.011970  0.012828  0.962505  0.012697    3
# 21  1.407370e+18  0.006750  0.006857  0.006736  0.979657    4
# 22  1.407400e+18  0.009695  0.009887  0.009834  0.970584    4
# 23  1.407420e+18  0.016732  0.016939  0.017052  0.949277    4
# 24  1.407430e+18  0.010640  0.967873  0.010825  0.010663    2
# 25  1.407440e+18  0.012975  0.013107  0.013239  0.960680    4
# 26  1.407470e+18  0.002537  0.002579  0.992360  0.002524    3
# 27  1.407480e+18  0.006895  0.685097  0.007064  0.300943    2
# 28  1.407490e+18  0.008025  0.975894  0.008076  0.008004    2
# 29  1.407500e+18  0.003707  0.003738  0.988947  0.003608    3

# %%
##Visualization of words

topic_word_prob=[]

for z in range(zk):
    word=[]
    prob=[]
    topic = lda.show_topic(z,1000) #No. of words

    for t in topic:
        word.append(t[0])
        prob.append(t[1])
        
    df_lda=pd.DataFrame({"word":word,"prob":prob})
    topic_word_prob.append(df_lda)

fig = plt.figure(figsize=(21, 12))

for z in range(zk):
    topic_text=[]
    for index, row in topic_word_prob[z].iloc[:2000,].iterrows():
        word=row["word"]
        weight=int(row["prob"]*1000)
        for _ in range(weight):
            topic_text.append(word)
            
    words = Counter(topic_text)
    wc_bz = WordCloud(background_color="white",
                      width=600, 
                      height=400, 
                      max_words=3000, 
                      max_font_size=70, 
                      font_path=fpath,
                      prefer_horizontal=1,
                      include_numbers=True,
                      colormap='tab20',
                      regexp=r"[\w']+")
    wc_bz.generate_from_frequencies(words)

    plt.figure(figsize = (21,12))
    sns.set_style("whitegrid")
    plt.title('Topic_{}'.format(z+1), fontsize=30)
    plt.imshow(wc_bz, interpolation='bilinear')
    plt.axis("off")
    
    # topic groups output to png
    output_dir = "/Users/motoki/PycharmProjects/motoki_ul/review_analysis/output_dir/twitter_mixed"
    pngname =  f"{today}_{category}_{zk}TWtopics"
    plt.savefig(f'{output_dir}/{pngname}_{z+1}.png')
    plt.show()

# %%
##Word2Vec Analysis
from gensim.models import word2vec

sent = text_combined
#Learning word2vec model
model = word2vec.Word2Vec(sent,
                          vector_size=50,  # Demention of vector (depends on the number of unique words)
                          min_count=3,  # Words appearing at least 2 times
                          window=5,  # Width of window
                          epochs=4000,  # Iter numbers of leaning
                          seed=2018 # Fix seed for generating stable random number
                         )

# %%
word = "ちゃう"
# Output the most similar words & similarity index
results = model.wv.most_similar(positive=word,topn=20)  
# Show in DataFrame
df_result = pd.DataFrame(results,columns=["Word","Sim"])
print("_{}_".format(word))
display(df_result.T)
# Out:
# _ちゃう_
#             0         1         2         3         4         5         6   \
# Word        季節       tea         b      ルイボス         神       しまっ      food
# Sim   0.466512  0.393344  0.381071  0.375376  0.357756  0.353547  0.348978
#
#             7         8         9         10        11        12        13  \
# Word       我が家       レモン        心配      ミックス    foodie         ﾟ        お腹
# Sim   0.339801  0.339028  0.337887  0.327928  0.324218  0.321982  0.318069
#
#             14       15       16        17        18        19
# Word      かわいい        産       後味        軽く         w       ベース
# Sim   0.315103  0.30561  0.30362  0.301952  0.299144  0.296573

# %%
## Plus/Minus words and show the similarities
results = model.wv.most_similar(positive=[u"ルイボス",u"美味しい"], negative=[u"フルーツ"], topn=20)
df_result = pd.DataFrame(results,columns=["Word","Sim"])
display(df_result.T)
# Out:
#             0         1         2         3         4         5         6   \
# Word        子供   ルイボスティー        飲み       少なく         母       バニラ        健康
# Sim   0.491984  0.428961  0.363454  0.339553  0.327391  0.296987  0.286571
#
#             7         8         9         10        11       12        13  \
# Word        なる         １       酸っぱ        入っ        いる   ルイボスティ       口コミ
# Sim   0.282587  0.280377  0.276089  0.261365  0.254071  0.25315  0.239916
#
#             14        15        16       17        18        19
# Word        でき        思い        水筒       種類        注ぐ        作る
# Sim   0.239635  0.230769  0.228517  0.21024  0.207163  0.206145

# %%
#Make array of mean vector b/w No. of products & vector dementions
product_vec = np.zeros((df_new_combined.shape[0],50))

for i,product in enumerate(text_combined):
    print(df_new_combined.tweet_id[i])
    feature_vec = np.zeros(50)
    num_words = 0
    for word in product:
        try:
            feature_vec += model.wv[word]
            num_words += 1
        except:
            print(f"{word}_is_not_in_dic")
    feature_vec = feature_vec / num_words  # Split sum of all the words vector
    product_vec[i] = feature_vec

##t-SNE for Word2Vec
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, verbose=1, n_iter=500)
tsne_word2vec = tsne.fit_transform(product_vec)
# Out:
# 1406564038851452930
# 1406644964805648385
# 1406950386737373187
# リプトン_is_not_in_dic
# 1407350720865705992
# 水彩_is_not_in_dic
# クッキー_is_not_in_dic
# クッキー_is_not_in_dic
# 水彩_is_not_in_dic
# 1408054853809545221
# はちみつ_is_not_in_dic
# 香り_is_not_in_dic
# はちみつ_is_not_in_dic
# 1408222421253967873
# リプトン_is_not_in_dic
# 香り_is_not_in_dic
# [t-SNE] Computing 5 nearest neighbors...
# [t-SNE] Indexed 6 samples in 0.000s...
# [t-SNE] Computed neighbors for 6 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 6 / 6
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 41.810787
# [t-SNE] KL divergence after 500 iterations: 0.131003

# %%
#Put in DataFrame
df_tsne_word2vec = pd.DataFrame(tsne_word2vec[:, 0],columns = ["x"])
df_tsne_word2vec["y"] = pd.DataFrame(tsne_word2vec[:, 1])
df_tsne_word2vec["tweet_id"] = df_new_combined.tweet_id
df_tsne_word2vec["kwd"] = df_new_combined.kwd

pd.set_option('display.max_rows', 1000)
display(df_tsne_word2vec.head(10))

##Visualization
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.rcParams['font.family'] = 'IPAexGothic'

#A: Overlook
fig_overview_word2vec = plt.figure(figsize=(10.0, 10.0))
for f in df_tsne_word2vec['kwd'].unique():
    plt.scatter(df_tsne_word2vec.loc[df_tsne_word2vec.kwd == f ,'x'], df_tsne_word2vec.loc[df_tsne_word2vec.kwd == f ,'y'], label=f)

plt.legend()
plt.title("Word2Vec-overview-")

#B: Detail
fig_detail_word2vec = plt.figure(figsize=(50.0, 30.0))
for f in df_tsne_word2vec['kwd'].unique():
    plt.scatter(df_tsne_word2vec.loc[df_tsne_word2vec.kwd == f ,'x'], df_tsne_word2vec.loc[df_tsne_word2vec.kwd == f ,'y'], label=f)

for i, txt in enumerate(df_tsne_word2vec["tweet_id"].values):
    plt.annotate(txt, (df_tsne_word2vec["x"].values[i], df_tsne_word2vec["y"].values[i]), fontsize=8)
    
plt.legend()
plt.title("Word2Vec")

plt.show()
# Out:
#             x           y             tweet_id       kwd
# 0   83.345459  -15.442652  1406564038851452930  アップルルイボス
# 1 -126.565140  -32.955811  1406644964805648385  アップルルイボス
# 2  -96.770744   93.771255  1406950386737373187  アップルルイボス
# 3  -15.248045 -100.453194  1407350720865705992  アップルルイボス
# 4  -24.455044    9.903551  1408054853809545221  アップルルイボス
# 5   32.961926  104.595718  1408222421253967873  アップルルイボス

# %%
##Doc2Vec analysis

from gensim.models.doc2vec import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
from gensim import corpora, models

trainings_combined = [TaggedDocument(words=data, tags=[name]) for (name, data) in zip(df_new_combined["tweet_id"], text_combined)]

# Learning model
model_doc_combined = models.Doc2Vec(
    documents=trainings_combined,
    vector_size=50,
    min_count=2,
    epochs=4000
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-168-a8e290d33e03> in <module>
#       8
#       9 # Learning model
# ---> 10 model_doc_combined = models.Doc2Vec(
#      11     documents=trainings_combined,
#      12     vector_size=50,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/doc2vec.py in __init__(self, documents, corpus_file, vector_size, dm_mean, dm, dbow_words, dm_concat, dm_tag_count, dv, dv_mapfile, comment, trim_rule, callbacks, window, epochs, **kwargs)
#     285         self.dv.vectors_lockf = np.ones(1, dtype=REAL)  # 0.0 values suppress word-backprop-updates; 1.0 allows
#     286
# --> 287         super(Doc2Vec, self).__init__(
#     288             sentences=corpus_iterable,
#     289             corpus_file=corpus_file,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab)
#     416         if corpus_iterable is not None or corpus_file is not None:
#     417             self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
# --> 418             self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
#     419             self.train(
#     420                 corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/doc2vec.py in build_vocab(self, corpus_iterable, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     864
#     865         """
# --> 866         total_words, corpus_count = self.scan_vocab(
#     867             corpus_iterable=corpus_iterable, corpus_file=corpus_file,
#     868             progress_per=progress_per, trim_rule=trim_rule
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/doc2vec.py in scan_vocab(self, corpus_iterable, corpus_file, progress_per, trim_rule)
#    1034             corpus_iterable = TaggedLineDocument(corpus_file)
#    1035
# -> 1036         total_words, corpus_count = self._scan_vocab(corpus_iterable, progress_per, trim_rule)
#    1037
#    1038         logger.info(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gensim/models/doc2vec.py in _scan_vocab(self, corpus_iterable, progress_per, trim_rule)
#     987             for key in doctags_list:
#     988                 doctags_lookup[key].index = doctags_lookup[key].index + max_rawint + 1
# --> 989             doctags_list = list(range(0, max_rawint + 1)) + doctags_list
#     990
#     991         self.dv.index_to_key = doctags_list
#
# MemoryError:

# %%
word = "リプトン"
# Output the most similar words & similarity index
results = model_doc_combined.wv.most_similar(positive=word,topn=20)  
# Show in DataFrame
df_result = pd.DataFrame(results,columns=["Word","Sim"])
print("_{}_".format(word))
display(df_result.T)
# Out:
# _リプトン_
#             0         1        2         3        4         5         6   \
# Word        トワ       温かい     イニング        一番     気に入っ        綺麗        購入
# Sim   0.535167  0.441997  0.42409  0.359616  0.35638  0.355789  0.332568
#
#            7         8         9         10        11        12        13  \
# Word       思い       安かっ        癒さ        毎年        異国        効い      美味しく
# Sim   0.31348  0.302193  0.300955  0.299515  0.297638  0.291877  0.284169
#
#            14        15       16        17        18        19
# Word        母        濃く        ０      かわいい        向け        暑い
# Sim   0.28322  0.278115  0.27741  0.259111  0.250586  0.249902

# %%
## Plus/Minus words and show the similarities
results = model_doc_combined.wv.most_similar(positive=[u"リプトン",u"安い"], negative=[u"フルーツ"], topn=20)
df_result = pd.DataFrame(results,columns=["Word","Sim"])
display(df_result.T)
# Out:
#             0         1         2         3         4         5         6   \
# Word        香り        トワ        コス        癒さ        毎年      気に入っ        綺麗
# Sim   0.372038  0.358927  0.339417  0.338398  0.334616  0.324355  0.319897
#
#             7         8         9         10        11        12        13  \
# Word        思い        定期        安心        購入        向け       はまっ        飲む
# Sim   0.317904  0.307789  0.302372  0.288592  0.288399  0.281103  0.277634
#
#             14       15        16        17       18        19
# Word      イニング    パッケージ        でる        感想       お茶         母
# Sim   0.275786  0.27345  0.260004  0.258803  0.25166  0.251638

# %%
## Find similar items(documents)
results = model_doc_combined.docvecs.most_similar(positive="リプトン ヘルシースタイル カモミール・オレンジ ティーバッグ 1箱（10バッグ入）")
df_result = pd.DataFrame(results,columns=["Word","Sim"])
display(df_result.T)
# Out:
# <ipython-input-61-b771ea8573ae>:2: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   results = model_doc_combined.docvecs.most_similar(positive="リプトン ヘルシースタイル カモミール・オレンジ ティーバッグ 1箱（10バッグ入）")
#                                0                               1  \
# Word  ポンパドール カモミールティー 1箱（20バッグ入）  伊藤園　ヘルシールイボスティー　500ml　1箱（24本入）
# Sim                      0.54276                        0.501323
#
#                                               2  \
# Word  ポンパドール ハーブティーローズヒップ 1セット（60バッグ：20バッグ入×3箱）
# Sim                                    0.492985
#
#                                                       3  \
# Word  山本漢方製薬　山本　カモミール100%　4979654024549　1箱（2g×20包）　ハ...
# Sim                                             0.47014
#
#                                                   4  \
# Word  生活の木 私の30日茶 女性の味方ブレンド 1箱（30ヶ入） ハーブティー（ティーバッグ）
# Sim                                         0.45922
#
#                                                       5  \
# Word  【 ハーブティー 】　フルーツガーデン ブラッドオレンジ 1袋  125g ［ ノンカフェイ...
# Sim                                             0.45398
#
#                                           6  \
# Word  ルピシア ハーブティー キャラメル＆ラム 1缶（50g）【ノンカフェイン】
# Sim                                 0.45277
#
#                                                    7  \
# Word  生活の木 私の30日茶 高麗人参剛力ブレンド 1箱（30ヶ入） ハーブティー（ティーバッグ）
# Sim                                         0.448062
#
#                                            8  \
# Word  生活の木 ルイボスバニラモカ 1袋（40ヶ入） ハーブティー（ティーバッグ）
# Sim                                 0.440716
#
#                                                       9
# Word  ポンパドール ポンパドールハーブティーカモミールティー 1セット（60バッグ：20バッグ入×...
# Sim                                            0.436387

# %%
#Make array of mean vector b/w No. of products & vector dementions
product_vec_doc = np.zeros((df_new_combined.shape[0],50))

for i,product in enumerate(text_combined):
    print(df_new_combined.tweet_id[i])
    feature_vec_doc = np.zeros(50)
    num_words_doc = 0
    for word in product:
        try:
            feature_vec_doc += model_doc_combined.wv[word]
            num_words_doc += 1
        except:
            print(f"{word}_is_not_in_dic")
    feature_vec_doc = feature_vec_doc / num_words_doc  # Split sum of all the words vector
    product_vec_doc[i] = feature_vec_doc

##t-SNE for Doc2Vec
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, verbose=1, n_iter=500)
tsne_doc2vec = tsne.fit_transform(product_vec_doc)
# Out:
# DEAN&DELUCA（ディーンアンドデルーカ）　ティーセレクション　ハーバル&フレーバー　1箱（6個入）
# LEBENSBAUM（レーベンスバウム） オーガニック 20種類のワールドトラベルアソートティー 1個（1.5g～2g×20袋） ハーブティー
# LEBENSBAUM（レーベンスバウム） ヤノッシュシリーズ お試しセット ハーブティー
# Wismettacフーズ　セレッシャル　スリーピータイム　1箱（20バッグ入）
# Wismettacフーズ　セレッシャル　ハニーバニラカモミール　1箱（20バッグ入）
# Wismettacフーズ　セレッシャル　ハーブ5種アソートセット　1箱（18バッグ入）
# 【 ハーブティー 】　フルーツガーデン ストロベリークリーム 1袋 125g ［ ノンカフェイン フルーツ入り ］
# 【 ハーブティー 】　フルーツガーデン ハワイカクテル 1袋 125g ［ ノンカフェイン フルーツ入り ］
# 【 ハーブティー 】　フルーツガーデン ブラッドオレンジ 1袋  125g ［ ノンカフェイン フルーツ入り ］
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー すっきりメロン 52504 50g1個
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー めぐり苺 52500 50g1個
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー ビタカシス 52502 50g1個
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー ビタカシス 52502 50g×3個
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー ビューティーイチジク 52506 50g1個
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー 林檎はちみつシナモン 52510 50g1個
# 【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティーシャンピーチ 52512 50g1個
# 【アウトレット】セレッシャル オーガニック カモミールラベンダー 1箱（20バッグ入）
# 【アウトレット】フルーツガーデン フルーツパラダイス 1袋（125g）
# 【ノンカフェイン】　国太楼　ルイボスティー　1袋（100バッグ入）
# 【ノンカフェイン】ティーライフ ルイボスティ ティーバッグ 1セット（303バッグ：101バッグ入×3袋）
# 【ノンカフェイン】ティーライフ ルイボスティ ティーバッグ 1袋（101バッグ入）
# 【ノンカフェイン】国太楼　ルイボスティー　1セット（300バッグ：100バッグ入×3袋）
# 【ワゴンセール】SONNENTOR（ゾネントア） ウィンターギフトアソート ジンジャーブレッドタイム（18袋入） 1個
# 【ワゴンセール】SONNENTOR（ゾネントア） クリスマス カウントダウン ハーブティー（24袋入） 1個
# 【ワゴンセール】【水出し可】伊藤園 ヘルシールイボスティー 1袋（3.0g×60バッグ入）
# 【成城石井】バーゲンダル 有機ルイボスティー 1箱80P入
# 【水出し可】 伊藤園 お徳用 ヘルシールイボスティー ティーバッグ 1袋（100バッグ入）
# 【水出し可】アスクル×ルピシア オリジナルルイボスブレンド ルイボス＆ローズヒップ ティーバッグ  1パック（30個入）
# 【水出し可】伊藤園 KEEP IN MY BOTTLE（キープインマイボトル） ルイボス＆ハーブティー 1袋（7バッグ入）
# 【水出し可】伊藤園 ヘルシー ルイボスティー ティーバッグ 1袋（15バッグ入） ハーブティー（ティーバッグ）
# がんこ茶家　ルイボスティーテトラティーバッグ　1袋（20バッグ入）　ハーブティー（ティーバッグ）
# れもん湯 1セット（6包入×3袋） 今岡製菓
# れもん湯 1セット（6包入×6袋） 今岡製菓
# キャメル珈琲 カルディオリジナル マテ茶 ロースト 1袋（16バッグ入）
# セレッシャル　フルーツ5種アソートセット　1箱（18バッグ入）
# トワイニング カモミール ティーバッグ　1箱（10バッグ入）
# トワイニング ローズヒップ＆ハイビスカス 1箱（10バッグ入）
# トワイニング　ハーブティーペパーミント　1箱（10バッグ入）
# トワイニング　レモン＆ジンジャーティーバッグ　1箱（10個入）
# ハラダ製茶 おいしいルイボスティー 1袋（52バッグ入）
# フルーツガーデン ハワイカクテル 1袋（10バッグ入）
# ポンパドール 4アソートハーブティー フルーツブレンド 1箱（18バッグ入）
# ポンパドール オーガニック オリエンタルチャイ 1箱（20バッグ入）
# ポンパドール オーガニック ユアマイベリー 1箱（20バッグ入）
# ポンパドール カモミールティー 1箱（20バッグ入）
# ポンパドール スパニッシュオレンジハーブティー 44g 1箱（20バッグ入）【ノンカフェイン】
# ポンパドール ハーブティーローズヒップ 1セット（60バッグ：20バッグ入×3箱）
# ポンパドール ハーブティーローズヒップ 1箱（20バッグ入）
# ポンパドール ペパーミントティー 1箱（20バッグ入）
# ポンパドール ポンパドールハーブティーカモミールティー 1セット（60バッグ：20バッグ入×3箱）【ノンカフェイン】
# ポンパドール ポンパドールハーブティーペパーミントティー 1セット（60バッグ：20バッグ入×3箱）【ノンカフェイン】
# リプトン ヘルシースタイル カモミール・オレンジ ティーバッグ 1箱（10バッグ入）
# リプトン ヘルシースタイル ローズヒップ・オレンジ ティーバッグ 1箱（10バッグ入）
# リプトン リプトン ハーブティーアソート5種 1箱（60バッグ入）
# ルピシア ハーブティー キャラメル＆ラム 1缶（50g）【ノンカフェイン】
# ルピシア ハーブティー ピッコロ 1缶（50g）【ノンカフェイン】
# ルピシア ハーブティー ピッコロ ティーバッグ（10個入）【ノンカフェイン】
# 伊藤園　ヘルシールイボスティー　500ml　1セット（6本）
# 伊藤園　ヘルシールイボスティー　500ml　1箱（24本入）
# 国太楼　有機ルイボスティー三角ティーバッグ　2個（1個20袋入×2）　1セット　ハーブティー（ティーバッグ）
# 大井川茶園 ダブルルイボスティーティーバッグ 1袋（24バッグ入）
# 山本漢方製薬　山本　カモミール100%　4979654024549　1箱（2g×20包）　ハーブティー（ティーバッグ）
# 成城石井 ガスコ　ルイボスチャイ　1袋30個入
# 成城石井 バーゲンダル 有機グリーンルイボステイー 20P 6009706220518 1個
# 日東紅茶　水出しピーチティー＆ローズヒップ ティーバッグ　1セット（36バッグ：12バッグ入×3袋）
# 日東紅茶　水出しピーチティー＆ローズヒップ ティーバッグ　1袋（12バッグ入）
# 河村農園　有機栽培ルイボスティー　1袋（30バッグ入）
# 片岡物産 トワイニング ハーブティー バラエティパック 1箱（40バッグ入）
# 片岡物産 トワイニング ハーブティー バラエティパック カフェインゼロ 1箱（8バッグ入）
# 生活の木 おいしいハーブティーエキナセアベア 1箱（10ヶ入） ハーブティー（ティーバッグ）
# 生活の木 おいしいハーブティーエルダーフラワーマスカット 1箱（10ヶ入） ハーブティー（ティーバッグ）
# 生活の木 おいしいハーブティーマヌカハニージンジャー 1箱（10ヶ入） ハーブティー（ティーバッグ）
# 生活の木 ベビーの有機ルイボスティー 1袋（30ヶ入） ハーブティー（ティーバッグ）
# 生活の木 ルイボスバニラモカ 1箱（15ヶ入） ハーブティー（ティーバッグ）
# 生活の木 ルイボスバニラモカ 1袋（40ヶ入） ハーブティー（ティーバッグ）
# 生活の木 私の30日茶 女性の味方ブレンド 1箱（30ヶ入） ハーブティー（ティーバッグ）
# 生活の木 私の30日茶 女性の味方ブレンド 1袋（7ヶ入） ハーブティー（ティーバッグ）
# 生活の木 私の30日茶 軽やかサラシアブレンド 1箱（30ヶ入） ハーブティー（ティーバッグ）
# 生活の木 私の30日茶 高麗人参剛力ブレンド 1箱（30ヶ入） ハーブティー（ティーバッグ）
# 生活の木 私の30日茶 高麗人参剛力ブレンド 1袋（7ヶ入） ハーブティー（ティーバッグ）
# [t-SNE] Computing 79 nearest neighbors...
# [t-SNE] Indexed 80 samples in 0.000s...
# [t-SNE] Computed neighbors for 80 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 80 / 80
# [t-SNE] Mean sigma: 1.447788
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.548035
# [t-SNE] KL divergence after 500 iterations: 0.860837

# %%
#Put in DataFrame
df_tsne_doc2vec = pd.DataFrame(tsne_doc2vec[:, 0],columns = ["x"])
df_tsne_doc2vec["y"] = pd.DataFrame(tsne_doc2vec[:, 1])
df_tsne_doc2vec["tweet_id"] = df_new_combined.tweet_id
df_tsne_doc2vec["kwd"] = df_new_combined.kwd

pd.set_option('display.max_rows', 1000)
display(df_tsne_doc2vec.head(10))

##Visualization
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.rcParams['font.family'] = 'IPAexGothic'

#A: Overlook
fig_overview_doc2vec = plt.figure(figsize=(10.0, 10.0))
for f in df_tsne_doc2vec['kwd'].unique():
    plt.scatter(df_tsne_doc2vec.loc[df_tsne_doc2vec.kwd == f ,'x'], df_tsne_doc2vec.loc[df_tsne_doc2vec.kwd == f ,'y'], label=f)

plt.legend()
plt.title("Doc2Vec-overview-")

#B: Detail
fig_detail_doc2vec = plt.figure(figsize=(50.0, 30.0))
for f in df_tsne_doc2vec['kwd'].unique():
    plt.scatter(df_tsne_doc2vec.loc[df_tsne_doc2vec.kwdd == f ,'x'], df_tsne_doc2vec.loc[df_tsne_doc2vec.kwd == f ,'y'], label=f)

for i, txt in enumerate(df_tsne_doc2vec["tweet_id"].values):
    plt.annotate(txt, (df_tsne_doc2vec["x"].values[i], df_tsne_doc2vec["y"].values[i]), fontsize=8)
    
plt.legend()
plt.title("Doc2Vec")

plt.show()
# Out:
#            x          y                                       product_name  \
# 0 -45.109653  79.046638  DEAN&DELUCA（ディーンアンドデルーカ）　ティーセレクション　ハーバル&フレーバー　...
# 1  12.106108   1.592252  LEBENSBAUM（レーベンスバウム） オーガニック 20種類のワールドトラベルアソートテ...
# 2  17.036133  11.622809       LEBENSBAUM（レーベンスバウム） ヤノッシュシリーズ お試しセット ハーブティー
# 3  24.627947  22.885389            Wismettacフーズ　セレッシャル　スリーピータイム　1箱（20バッグ入）
# 4   2.782181  10.985058         Wismettacフーズ　セレッシャル　ハニーバニラカモミール　1箱（20バッグ入）
# 5  -8.521563 -69.922462        Wismettacフーズ　セレッシャル　ハーブ5種アソートセット　1箱（18バッグ入）
# 6 -37.420597   3.177659  【 ハーブティー 】　フルーツガーデン ストロベリークリーム 1袋 125g ［ ノンカフェ...
# 7  87.071495  38.387630  【 ハーブティー 】　フルーツガーデン ハワイカクテル 1袋 125g ［ ノンカフェイン ...
# 8 -68.426849  27.638330  【 ハーブティー 】　フルーツガーデン ブラッドオレンジ 1袋  125g ［ ノンカフェイ...
# 9  51.686825 -58.242813  【アウトレット】VECUA Honey ハニーマルシェ 食べる果実のフルーティー すっきりメ...
#
#                     brand
# 0               ディーン＆デルーカ
# 1        SONNENTOR（ゾネントア）
# 2    LEBENSBAUM（レーベンスバウム）
# 3           セレッシャルシーズニングス
# 4           セレッシャルシーズニングス
# 5           セレッシャルシーズニングス
# 6  Fruit Garden（フルーツガーデン）
# 7  Fruit Garden（フルーツガーデン）
# 8  Fruit Garden（フルーツガーデン）
# 9    VECUA Honey（ベキュアハニー）
